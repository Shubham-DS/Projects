# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Aayushi\Desktop\Data Science\CSV files\covid_19_dat.csv')
df.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
df.shape
# Out:
# (321, 6)

# %%
df.isna().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
df.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
#Show the number of confirmed,deaths and recovered in each region
df.groupby('Region').sum().head()
df.groupby('Region')['Recovered','Deaths','Confirmed'].sum().head()
# Out:
#              Recovered  Deaths  Confirmed
# Region
# Afghanistan        252      60       1939
# Albania            455      30        766
# Algeria           1702     444       3848
# Andorra            423      42        743
# Angola               7       2         27

# %%
#Remove all the records where confirmed cases is less than 10
df[(df['Confirmed']<10)].shape
# Out:
# (17, 6)

# %%
df[~(df['Confirmed']<10)].head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
#In which region , maximum number of confirmed cases are recorded
rt=np.where(df['Confirmed']==df['Confirmed'].max())
dg=df.loc[rt]
dg.head()
# Out:
#           Date     State Region  Confirmed  Deaths  Recovered
# 265  4/29/2020  New York     US     299691   23477          0

# %%
#In which region , minimum number of deaths are recorded
qw=np.where(df['Deaths']==df['Deaths'].min())
we=df.loc[qw]
we.head()
# Out:
#          Date State                    Region  Confirmed  Deaths  Recovered
# 18  4/29/2020   NaN                    Bhutan          7       0          5
# 29  4/29/2020   NaN                  Cambodia        122       0        119
# 31  4/29/2020   NaN  Central African Republic         50       0         10
# 45  4/29/2020   NaN                  Dominica         16       0         13
# 51  4/29/2020   NaN                   Eritrea         39       0         19

# %%
#How many confirmed,deaths,recoverd are recorded in India till April 2020
er=np.where(df['Region']=='India')
gh=df.loc[er]
gh.head()
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
#Sort the entire data wrt confirmed cases in ascending order
df.sort_values(by=['Confirmed'])
# Out:
#           Date                             State                 Region  \
# 285  4/29/2020                         Recovered                     US
# 284  4/29/2020                         Recovered                 Canada
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 305  4/29/2020                             Tibet         Mainland China
# 289  4/29/2020         Saint Pierre and Miquelon                 France
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 272  4/29/2020             Northwest Territories                 Canada
# 288  4/29/2020                  Saint Barthelemy                 France
# 178  4/29/2020                               NaN                  Yemen
# 194  4/29/2020            British Virgin Islands                     UK
# 177  4/29/2020                               NaN         Western Sahara
# ...

# %%
#Sort the entire data wrt the number of recovered cases in descending order
df.sort_values(by=['Recovered'],ascending=False)
# Out:
#           Date                      State            Region  Confirmed  \
# 153  4/29/2020                        NaN             Spain     236899
# 285  4/29/2020                  Recovered                US          0
# 61   4/29/2020                        NaN           Germany     161539
# 76   4/29/2020                        NaN              Iran      93657
# 80   4/29/2020                        NaN             Italy     203591
# 229  4/29/2020                      Hubei    Mainland China      68128
# 57   4/29/2020                        NaN            France     165093
# 167  4/29/2020                        NaN            Turkey     117589
# 22   4/29/2020                        NaN            Brazil      79685
# 158  4/29/2020                        NaN       Switzerland      29407
# 284  4/29/2020                  Recovered            Canada          0
# 78   4/29/2020                        NaN           Ireland      20253
# ...
